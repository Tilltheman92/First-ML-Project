# %%
#Importing libaries
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle

# %%
#Using https://archive.ics.uci.edu/ml/datasets/student+performance dataset
#read data
#check data
data = pd.read_csv("student-mat.csv", sep=";")
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
#Taking important columns
data = data[["G1", "G2", "G3", "studytime", "failures", "absences"]]

# %%
#set featueres and labels
#predcit is label rest is features
predict = "G3"
X = np.array(data.drop([predict], 1)) # Features
y = np.array(data[predict]) # Labels

# %%
#assigning multiple variables
#and setting model 
#creating 4 arrays: 2 to train and 2 to test it.
#So wont use all data to train
#10% will be to test the model
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.1)

# %%
#define model
linear = linear_model.LinearRegression()
linear.fit(x_train, y_train)
#then test accuracy
acc = linear.score(x_test, y_test)
acc
#So predicting G3 with 62% accuracy based on G2 G1 studytime failures and absences
# Out:
# 0.621629759728696

# %%
#Show the used Constants by the model
print('Coefficient: \n', linear.coef_) # These are each slope value for each varaible
print('Intercept: \n', linear.intercept_) # This is the intercept
# Out:
# Coefficient:
#  [ 0.16239229  0.95661262 -0.20832687 -0.26448499  0.04047233]
# Intercept:
#  -1.2200690668740908

# %%
#check for specific student
#list of all predictions
predictions = linear.predict(x_test) 
#checking prediction of model, and actual data for g3
for x in range(len(predictions)):
    print(predictions[x], x_test[x], y_test[x])
# Out:
# 8.804034631706456 [8 9 1 0 8] 10
# 11.63213868813794 [10  9  2  0 75] 9
# 12.114611828728055 [11 12  2  0 12] 11
# 7.31531647883995 [8 8 2 0 0] 0
# 3.810274473814448 [7 5 3 1 0] 0
# 6.230818704107466 [7 7 3 0 6] 7
# 8.350547075012758 [ 9  9  2  2 11] 9
# 7.31531647883995 [8 8 2 0 0] 0
# 9.95905554564781 [12 10  2  0  2] 11
# 8.465955371863217 [ 7 10  4  1  2] 10
# 7.213223778351802 [9 8 2 1 0] 0
# 9.288841307408502 [10 10  2  1  0] 0
# 3.0058305952850004 [7 4 1 2 0] 0
# 13.841204696712264 [13 13  2  0 23] 13
# 10.752772918312353 [10 11  2  0  6] 11
# 15.466667272100194 [16 15  3  0  9] 16
# 8.052875726551092 [6 9 1 1 4] 8
# 11.791336117510088 [12 12  2  0  0] 11
# 15.102416270977942 [16 15  3  0  0] 15
# 7.141999704408139 [9 8 4 0 2] 8
# 15.734244309810373 [14 16  3  0  0] 16
# 19.420543453554565 [18 18  1  1 24] 18
# 9.244773970560555 [11  9  2  0 12] 9
# 11.942300967188757 [14 12  4  0  6] 13
# 12.249344425464452 [10 13  4  0  6] 13
# 7.883438016591111 [11  8  2  0  2] 8
# ...
